# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# # Question 1

# %% [markdown]
# # pout.tif Image

# %%
# read input as grayscale
img = cv2.imread('images/pout.tif', 0)

# convert image to floats and do dft saving as complex output
dft = cv2.dft(np.float32(img), flags = cv2.DFT_COMPLEX_OUTPUT)

# %%
# read input as grayscale
img = cv2.imread('images/pout.tif', 0)

# convert image to floats and do dft saving as complex output
dft = cv2.dft(np.float32(img), flags = cv2.DFT_COMPLEX_OUTPUT)

# apply shift of origin from upper left corner to center of image
dft_shift = np.fft.fftshift(dft)

# extract magnitude and phase images
mag, phase = cv2.cartToPolar(dft_shift[:,:,0], dft_shift[:,:,1])

# get spectrum for viewing only
spec = np.log(mag) / 20

# NEW CODE HERE: raise mag to some power near 1
# values larger than 1 increase contrast; values smaller than 1 decrease contrast
mag = cv2.pow(mag, 1.1)

# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag, phase)

# combine cartesian components into one complex image
back = cv2.merge([real, imag])

# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)

# do idft saving as complex output
img_back = cv2.idft(back_ishift)

# combine complex components into original image again
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

# re-normalize to 8-bits
min, max = np.amin(img_back, (0,1)), np.amax(img_back, (0,1))
print(min,max)
img_back = cv2.normalize(img_back, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

# plt.imshow("ORIGINAL", img)
# plt.imshow("MAG", mag)
# plt.imshow("PHASE", phase)
# plt.imshow("SPECTRUM", spec)
# plt.imshow("REAL", real)
# plt.imshow("IMAGINARY", imag)
# plt.imshow("COEF ROOT", img_back)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

figure, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(20,20))
ax1.imshow(img, cmap='gray')
ax1.set_title('Input Image pout'), ax1.set_xticks([]), ax1.set_yticks([])
ax2.imshow(spec, cmap='gray')
ax2.set_title('Ferequency Spectrum pout'), ax2.set_xticks([]), ax2.set_yticks([])
ax3.imshow(phase, cmap='gray')
ax3.set_title('Phase Spectrum pout'), ax3.set_xticks([]), ax3.set_yticks([])
plt.show()

# read input as grayscale
img2 = cv2.imread('images/cameraman.tif', 0)

# convert image to floats and do dft saving as complex output
dft2 = cv2.dft(np.float32(img2), flags = cv2.DFT_COMPLEX_OUTPUT)

# apply shift of origin from upper left corner to center of image
dft_shift2 = np.fft.fftshift(dft2)

# extract magnitude and phase images
mag2, phase2 = cv2.cartToPolar(dft_shift2[:,:,0], dft_shift2[:,:,1])

# get spectrum for viewing only
spec2 = np.log(mag2) / 20

# NEW CODE HERE: raise mag to some power near 1
# values larger than 1 increase contrast; values smaller than 1 decrease contrast
mag2 = cv2.pow(mag2, 1.1)

# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag, phase2)

# combine cartesian components into one complex image
back = cv2.merge([real, imag])

# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)

# do idft saving as complex output
img_back = cv2.idft(back_ishift)

# combine complex components into original image again
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])

# re-normalize to 8-bits
min, max = np.amin(img_back, (0,1)), np.amax(img_back, (0,1))
# print(min,max)
img_back = cv2.normalize(img_back, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

# cv2.imshow("ORIGINAL", img)
# cv2.imshow("MAG", mag)
# cv2.imshow("PHASE", phase)
# cv2.imshow("SPECTRUM", spec)
# cv2.imshow("REAL", real)
# cv2.imshow("IMAGINARY", imag)
# cv2.imshow("COEF ROOT", img_back)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

figure, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(20,20))
ax1.imshow(img2, cmap='gray')
ax1.set_title('Input Image cameraman'), ax1.set_xticks([]), ax1.set_yticks([])
ax2.imshow(spec2, cmap='gray')
ax2.set_title('Ferequency Spectrum cameraman'), ax2.set_xticks([]), ax2.set_yticks([])
ax3.imshow(phase2, cmap='gray')
ax3.set_title('Phase Spectrum cameraman'), ax3.set_xticks([]), ax3.set_yticks([])
plt.show()


# Using POUT Frequency and Cameraman Phase
# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag, phase2)
# combine cartesian components into one complex image
back = cv2.merge([real, imag])
# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)
# do idft saving as complex output
img_back = cv2.idft(back_ishift)
# combine complex components into original image again
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])
# re-normalize to 8-bits
min, max = np.amin(img_back, (0,1)), np.amax(img_back, (0,1))
# print(min,max)
img_back1 = cv2.normalize(img_back, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

# Using Cameraman Frequency and POUT Phase
# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag2, phase)
# combine cartesian components into one complex image
back = cv2.merge([real, imag])
# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)
# do idft saving as complex output
img_back = cv2.idft(back_ishift)
# combine complex components into original image again
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])
# re-normalize to 8-bits
min, max = np.amin(img_back, (0,1)), np.amax(img_back, (0,1))
# print(min,max)
img_back2 = cv2.normalize(img_back, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)


figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20,20))
ax1.imshow(img_back1, cmap='gray')
ax1.set_title('Image 1'), ax1.set_xticks([]), ax1.set_yticks([])
ax2.imshow(img_back2, cmap='gray')
ax2.set_title('Image 2'), ax2.set_xticks([]), ax2.set_yticks([])
plt.show()

phase.fill(2)
phase2.fill(2)
# Using Own Magnatiude and random phase
# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag, phase)
# combine cartesian components into one complex image
back = cv2.merge([real, imag])
# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)
# do idft saving as complex output
img_back = cv2.idft(back_ishift)
# combine complex components into original image again
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])
# re-normalize to 8-bits
min, max = np.amin(img_back, (0,1)), np.amax(img_back, (0,1))
# print(min,max)
img_back3 = cv2.normalize(img_back, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

# convert magnitude and phase into cartesian real and imaginary components
real, imag = cv2.polarToCart(mag2, phase2)
# combine cartesian components into one complex image
back = cv2.merge([real, imag])
# shift origin from center to upper left corner
back_ishift = np.fft.ifftshift(back)
# do idft saving as complex output
img_back = cv2.idft(back_ishift)
# combine complex components into original image again
img_back = cv2.magnitude(img_back[:,:,0], img_back[:,:,1])
# re-normalize to 8-bits
min, max = np.amin(img_back, (0,1)), np.amax(img_back, (0,1))
# print(min,max)
img_back4 = cv2.normalize(img_back, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_8U)

figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20,20))
ax1.imshow(img_back3, cmap='gray')
ax1.set_title('Image POUT'), ax1.set_xticks([]), ax1.set_yticks([])
ax2.imshow(img_back4, cmap='gray')
ax2.set_title('Image CAMERAMAN'), ax2.set_xticks([]), ax2.set_yticks([])
plt.show()
# Out:
# 27008382.0 54415164.0

# %% [markdown]
# # Question 2

# %%
# %matplotlib inline
from IPython.display import display, Math, Latex
import cv2
import numpy as np
import matplotlib.pyplot as plt

# img = Image.open('images/bean.png')
img = cv2.imread('images/bean.png', 0)

# display the image
plt.imshow(img, cmap='gray')

# %%
img = np.asarray(img)
flat = img.flatten()
plt.hist(flat, bins=50)
# Out:
# (array([5.000e+00, 1.200e+01, 2.400e+01, 1.020e+02, 1.070e+02, 2.619e+03,
#         1.911e+03, 7.480e+02, 5.424e+03, 1.059e+03, 2.909e+03, 9.530e+02,
#         1.879e+03, 1.641e+03, 7.540e+02, 1.466e+03, 8.250e+02, 1.624e+03,
#         1.952e+03, 1.211e+03, 2.484e+03, 1.312e+03, 2.180e+03, 1.232e+03,
#         2.448e+03, 2.503e+03, 1.281e+03, 2.582e+03, 1.263e+03, 2.349e+03,
#         1.113e+03, 2.137e+03, 1.922e+03, 8.500e+02, 1.622e+03, 7.270e+02,
#         1.340e+03, 1.112e+03, 4.860e+02, 8.800e+02, 4.200e+02, 7.610e+02,
#         3.360e+02, 7.470e+02, 6.240e+02, 1.620e+02, 3.040e+02, 5.400e+01,
#         3.800e+01, 6.000e+00]),
#  array([ 4.  ,  5.58,  7.16,  8.74, 10.32, 11.9 , 13.48, 15.06, 16.64,
#         18.22, 19.8 , 21.38, 22.96, 24.54, 26.12, 27.7 , 29.28, 30.86,
#         32.44, 34.02, 35.6 , 37.18, 38.76, 40.34, 41.92, 43.5 , 45.08,
#         46.66, 48.24, 49.82, 51.4 , 52.98, 54.56, 56.14, 57.72, 59.3 ,
# ...

# %%
# create our own histogram function
def get_histogram(image, bins):
    # array with size of bins, set to zeros
    histogram = np.zeros(bins)
    
    # loop through pixels and sum up counts of pixels
    for pixel in image:
        histogram[pixel] += 1
    
    # return our final result
    return histogram

# create our cumulative sum function
def cumsum(a):
    a = iter(a)
    b = [next(a)]
    for i in a:
        b.append(b[-1] + i)
    return np.array(b)

# execute our histogram function
hist = get_histogram(flat, 256)
# execute the fn
cs = cumsum(hist)
# display the result
plt.plot(cs)

# %%
# numerator & denomenator
nj = (cs - cs.min()) * 255
N = cs.max() - cs.min()

# re-normalize the cumsum
cs = nj / N

# cast it back to uint8 since we can't use floating point values in images
cs = cs.astype('uint8')

plt.plot(cs)

# %%
# get the value from cumulative sum for every index in flat, and set that as img_new
img_new = cs[flat]

# put array back into original shape since we flattened it
img_new = np.reshape(img_new, img.shape)

# set up side-by-side image display
fig = plt.figure()
fig.set_figheight(15)
fig.set_figwidth(15)

fig.add_subplot(1,2,1)
plt.imshow(img, cmap='gray')

# display the new image
fig.add_subplot(1,2,2)
plt.imshow(img_new, cmap='gray')

plt.show(block=True)

# cv2.imwrite('res.png',img_new)
# Out:
# True

# %% [markdown]
# # Question 3

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images/bone.jpg')

kernel = np.ones((7,7),np.float32)/49
dst = cv2.filter2D(img,-1,kernel)

plt.figure(figsize=(8,8))
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

cv2.imwrite('bone_averageMast.png',dst)
# Out:
# True

# %%
from scipy import fftpack
# read image
img = plt.imread('images/bone.jpg')

# First a 1-D  Gaussian
t = np.linspace(-10, 10, 35)
bump = np.exp(-0.1*t**2)
bump /= np.trapz(bump) # normalize the integral to 1

# make a 2-D kernel out of it
kernel = bump[:, np.newaxis] * bump[np.newaxis, :]

# Padded fourier transform, with the same shape as the image
# We use :func:`scipy.signal.fftpack.fft2` to have a 2D FFT
kernel_ft = fftpack.fft2(kernel, shape=img.shape[:2], axes=(0, 1))
# convolve
img_ft = fftpack.fft2(img, axes=(0, 1))
print(img_ft.shape)
# the 'newaxis' is to match to color direction
img2_ft = kernel_ft[:, :] * img_ft
img2 = fftpack.ifft2(img2_ft, axes=(0, 1)).real

# clip values to range
img2 = np.clip(img2, 0, 1)


from scipy import signal
# mode='same' is there to enforce the same output shape as input arrays
# (ie avoid border effects)
img3 = signal.fftconvolve(img, kernel[:, :], mode='same')


plt.figure(figsize=(8,8))
plt.subplot(121),plt.imshow(img, cmap='gray', vmin=0, vmax=255),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img3, cmap='gray', vmin=0, vmax=255),plt.title('Gaussian Blur')
plt.xticks([]), plt.yticks([])
plt.show()
cv2.imwrite('bone_Gassian.png',img3)
# Out:
# (893, 485)
# True

# %% [markdown]
# # Question 4

# %%
# Out:
# (35, 35)

# %%
# read image
img = plt.imread('images/char.tif')

bump = np.ones(35)
# make a 2-D kernel out of it
bump /= np.trapz(bump) # normalize the integral to 1
kernel = bump[:, np.newaxis] * bump[np.newaxis, :]

# Padded fourier transform, with the same shape as the image
# We use :func:`scipy.signal.fftpack.fft2` to have a 2D FFT
kernel_ft = fftpack.fft2(kernel, shape=img.shape[:2], axes=(0, 1))
# temp = int((img.shape[0]-35)/2)
# kernel_ft = np.pad(kernel, ((temp + 1,temp),(temp + 1,temp)), 'constant')
print(kernel_ft.shape)
# convolve
img_ft = fftpack.fft2(img, axes=(0, 1))
# the 'newaxis' is to match to color direction
img2_ft = kernel_ft[:, :] * img_ft
img2 = fftpack.ifft2(img2_ft, axes=(0, 1)).real

# clip values to range
img2 = np.clip(img2, 0, 1)


from scipy import signal
# mode='same' is there to enforce the same output shape as input arrays
# (ie avoid border effects)
img3 = signal.fftconvolve(img, kernel[:, :], mode='same')

plt.figure(figsize=(8,8))
plt.subplot(121),plt.imshow(img, cmap='gray', vmin=0, vmax=255),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img3, cmap='gray', vmin=0, vmax=255),plt.title('Gaussian Blur')
plt.xticks([]), plt.yticks([])
plt.show()
cv2.imwrite('bone_Gassian.png',img3)
# Out:
# (688, 688)
# True

# %%
# read image
img = plt.imread('images/char.tif')

# First a 1-D  Gaussian
t = np.linspace(-10, 10, 35)
bump = np.exp(-0.1*t**2)
bump /= np.trapz(bump) # normalize the integral to 1

# make a 2-D kernel out of it
kernel = bump[:, np.newaxis] * bump[np.newaxis, :]

# Padded fourier transform, with the same shape as the image
# We use :func:`scipy.signal.fftpack.fft2` to have a 2D FFT
kernel_ft = fftpack.fft2(kernel, shape=img.shape[:2], axes=(0, 1))
# convolve
img_ft = fftpack.fft2(img, axes=(0, 1))
print(img_ft.shape)
# the 'newaxis' is to match to color direction
img2_ft = kernel_ft[:, :] * img_ft
img2 = fftpack.ifft2(img2_ft, axes=(0, 1)).real

# clip values to range
img2 = np.clip(img2, 0, 1)


from scipy import signal
# mode='same' is there to enforce the same output shape as input arrays
# (ie avoid border effects)
img3 = signal.fftconvolve(img, kernel[:, :], mode='same')

plt.figure(figsize=(8,8))
plt.subplot(121),plt.imshow(img, cmap='gray', vmin=0, vmax=255),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img3, cmap='gray', vmin=0, vmax=255),plt.title('Gaussian Blur')
plt.xticks([]), plt.yticks([])
plt.show()
cv2.imwrite('bone_Gassian.png',img3)
# Out:
# (688, 688)
# True

# %% [markdown]
# # Question 5

# %%
kernel = np.zeros((3,3))
kernel[1][1] = 4
kernel[0][1] = kernel[1][0] = kernel[1][2] = kernel[2][1] = -1

dft = cv2.dft(np.float32(kernel), flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
mag, phase = cv2.cartToPolar(dft_shift[:,:,0], dft_shift[:,:,1])
print(kernel)
print(mag)
print(phase)

plt.imshow(kernel, cmap='gray')
plt.show()
plt.imshow(mag, cmap='gray')
plt.show()
plt.imshow(phase, cmap='gray')
plt.show()
# Out:
# [[ 0. -1.  0.]
#  [-1.  4. -1.]
#  [ 0. -1.  0.]]
# [[5.9999995 2.9999998 5.9999995]
#  [2.9999998 0.        2.9999998]
#  [5.9999995 2.9999998 5.9999995]]
# [[3.665151  5.759627  1.5707964]
#  [5.759627  0.        3.6651511]
#  [1.5707964 3.6651511 5.759627 ]]

# %% [markdown]
# # Question 6

# %%
def convolve2D(image, kernel, padding=0, strides=1):
    # Cross Correlation
    kernel = np.flipud(np.fliplr(kernel))

    # Gather Shapes of Kernel + Image + Padding
    xKernShape = kernel.shape[0]
    yKernShape = kernel.shape[1]
    xImgShape = image.shape[0]
    yImgShape = image.shape[0]

    # Shape of Output Convolution
    xOutput = int(((xImgShape - xKernShape + 2 * padding) / strides) + 1)
    yOutput = int(((yImgShape - yKernShape + 2 * padding) / strides) + 1)
    output = np.zeros((xOutput, yOutput))

    # Apply Equal Padding to All Sides
    if padding != 0:
        imagePadded = np.zeros((image.shape[0] + padding*2, image.shape[1] + padding*2))
        imagePadded[int(padding):int(-1 * padding), int(padding):int(-1 * padding)] = image
        print(imagePadded.shape)
    else:
        imagePadded = image

    # Iterate through image
    for y in range(image.shape[1]):
        # Exit Convolution
        if y > image.shape[1] - yKernShape:
            break
        # Only Convolve if y has gone down by the specified Strides
        if y % strides == 0:
            for x in range(image.shape[0]):
                # Go to next row once kernel is out of bounds
                if x > image.shape[0] - xKernShape:
                    break
                try:
                    # Only Convolve if x has moved by the specified Strides
                    if x % strides == 0:
                        output[x, y] = (kernel * imagePadded[x: x + xKernShape, y: y + yKernShape]).sum()
                except:
                    break

    return output

# read image
img = plt.imread('images/bld.tif')
print(img.shape)
kernel = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])
# Convolve and Save Output
output = convolve2D(img, kernel, padding=1)
print(output.shape)

plt.figure(figsize=(8,8))
plt.subplot(121),plt.imshow(img, cmap='gray', vmin=0, vmax=255),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(output, cmap='gray', vmin=0, vmax=255),plt.title('Laplacian filter in space domain')
plt.xticks([]), plt.yticks([])
plt.show()
cv2.imwrite('2DConvolved_bld_space.jpg', output)
# Out:
# (600, 600)
# (602, 602)
# (600, 600)
# True

# %%
# read image
img = plt.imread('images/bld.tif')

kernel = np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]])

kernel_ft = fftpack.fft2(kernel, shape=img.shape[:2], axes=(0, 1))

# convolve
img_ft = fftpack.fft2(img, axes=(0, 1))
print(img_ft.shape)

img2_ft = kernel_ft[:, :] * img_ft
img2 = fftpack.ifft2(img2_ft, axes=(0, 1)).real

img2 = np.clip(img2, 0, 1)

img3 = signal.fftconvolve(img, kernel[:, :], mode='same')

plt.figure(figsize=(8,8))
plt.subplot(121),plt.imshow(img, cmap='gray', vmin=0, vmax=255),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img3, cmap='gray', vmin=0, vmax=255),plt.title('Laplacian in frequency domain')
plt.xticks([]), plt.yticks([])
plt.show()
cv2.imwrite('2DConvolved_bld_frequency.jpg',img3)


dft = cv2.dft(np.float32(kernel), flags = cv2.DFT_COMPLEX_OUTPUT)
dft_shift = np.fft.fftshift(dft)
mag, phase = cv2.cartToPolar(dft_shift[:,:,0], dft_shift[:,:,1])
spec = np.log(mag) / 20

figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20,20))
ax1.imshow(img, cmap='gray')
ax1.set_title('Input Image pout'), ax1.set_xticks([]), ax1.set_yticks([])
ax2.imshow(spec, cmap='gray')
ax2.set_title('Ferequency Spectrum pout'), ax2.set_xticks([]), ax2.set_yticks([])
plt.show()
# Out:
# (600, 600)
# <ipython-input-138-dfccdcae9548>:31: RuntimeWarning: divide by zero encountered in log
#   spec = np.log(mag) / 20

# %% [markdown]
# # Question 7

# %%
# read image
img = plt.imread('images/fruits.png')
img = img[:,:, 2]
plt.imshow(img)
